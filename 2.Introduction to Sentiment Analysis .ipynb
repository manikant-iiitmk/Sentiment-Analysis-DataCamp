# %% [markdown]
#  **one could measure how long each review is, how many sentences it contains, or say something about the parts of speech involved, punctuation marks, etc.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#!pip install nltk

# %%
data_review= pd.read_csv('amazon_reviews_sample.csv')

# %%
data_review.head()
# Out:
#    Unnamed: 0  score                                             review
# 0           0      1   Stuning even for the non-gamer: This sound tr...
# 1           1      1   The best soundtrack ever to anything.: I'm re...
# 2           2      1   Amazing!: This soundtrack is my favorite musi...
# 3           3      1   Excellent Soundtrack: I truly like this sound...
# 4           4      1   Remember, Pull Your Jaw Off The Floor After H...

# %% [markdown]
# # Feature from Review Column

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tokenizing a string

# %%
from nltk import word_tokenize

# %% [markdown]
# **A first standard step when working with text is to tokenize it, in other words, split a bigger string into individual strings, which are usually single words (tokens).**

# %%
anna_k = 'Happy families are all alike, every unhappy family is unhappy in its own way'

# %%
word_tokenize(anna_k)
# Out:
# ['Happy',
#  'families',
#  'are',
#  'all',
#  'alike',
#  ',',
#  'every',
#  'unhappy',
#  'family',
#  'is',
#  'unhappy',
#  'in',
#  'its',
#  'own',
#  'way']

# %%
#import nltk
#nltk.download()

# %%
avengers=["Cause if we can't protect the Earth, you can be d*** sure we'll avenge it",
 'There was an idea to bring together a group of remarkable people, to see if we could become something more',
 "These guys come from legend, Captain. They're basically Gods."]

# %%
# Tokenize each item in the avengers 
tokens_avengers = [word_tokenize(avengers) for avengers in avengers]
#[word_tokenize(review) for review in data_review.review]
print(tokens_avengers)
# Out:
# [['Cause', 'if', 'we', 'ca', "n't", 'protect', 'the', 'Earth', ',', 'you', 'can', 'be', 'd***', 'sure', 'we', "'ll", 'avenge', 'it'], ['There', 'was', 'an', 'idea', 'to', 'bring', 'together', 'a', 'group', 'of', 'remarkable', 'people', ',', 'to', 'see', 'if', 'we', 'could', 'become', 'something', 'more'], ['These', 'guys', 'come', 'from', 'legend', ',', 'Captain', '.', 'They', "'re", 'basically', 'Gods', '.']]

# %%
word_tokens = [word_tokenize(review) for review in data_review.review]

# %%
word_tokens
# Out:
# [['Stuning',
#   'even',
#   'for',
#   'the',
#   'non-gamer',
#   ':',
#   'This',
#   'sound',
#   'track',
#   'was',
#   'beautiful',
#   '!',
#   'It',
#   'paints',
#   'the',
#   'senery',
#   'in',
#   'your',
#   'mind',
#   'so',
#   'well',
#   'I',
#   'would',
#   'recomend',
#   'it',
#   'even',
#   'to',
#   'people',
#   'who',
#   'hate',
#   'vid',
#   '.',
#   'game',
#   'music',
#   '!',
#   'I',
#   'have',
#   'played',
#   'the',
#   'game',
#   'Chrono',
#   'Cross',
#   'but',
#   'out',
#   'of',
#   'all',
#   'of',
#   'the',
#   'games',
#   'I',
#   'have',
#   'ever',
#   'played',
#   'it',
#   'has',
#   'the',
#   'best',
#   'music',
#   '!',
#   'It',
#   'backs',
#   'away',
#   'from',
#   'crude',
#   'keyboarding',
#   'and',
#   'takes',
#   'a',
#   'fresher',
#   'step',
#   'with',
#   'grate',
#   'guitars',
#   'and',
#   'soulful',
#   'orchestras',
#   '.',
#   'It',
#   'would',
#   'impress',
#   'anyone',
#   'who',
#   'cares',
# ...

# %% [markdown]
# # Tokens from a column

# %%
len_tokens = []
# Iterate over the word_tokens list
for i in range(len(word_tokens)):
    len_tokens.append(len(word_tokens[i]))

# %%
# Create a new feature for the length of each review
data_review['n_tokens'] = len_tokens

# %% [markdown]
# **You have used a list comprehension and a for loop to iterate over the word tokens created from the review column. You can employ the same approach to create other features, such as one counting the number of sentences in each review.**

# %%
data_review.head()
# Out:
#    Unnamed: 0  score                                             review  \
# 0           0      1   Stuning even for the non-gamer: This sound tr...
# 1           1      1   The best soundtrack ever to anything.: I'm re...
# 2           2      1   Amazing!: This soundtrack is my favorite musi...
# 3           3      1   Excellent Soundtrack: I truly like this sound...
# 4           4      1   Remember, Pull Your Jaw Off The Floor After H...
#
#    n_tokens
# 0        87
# 1       109
# 2       165
# 3       145
# 4       109

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # A feature for the length of a review
# 1. It is time to use a larger sample of data.
# 2. Create a new feature for the length of a review, using the familiar reviews dataset

# %%
# Tokenize each item in the review column 
word_tokens = [word_tokenize(review) for review in data_review.review]

# Print out the first item of the word_tokens list
print(word_tokens[0])
# Out:
# ['Stuning', 'even', 'for', 'the', 'non-gamer', ':', 'This', 'sound', 'track', 'was', 'beautiful', '!', 'It', 'paints', 'the', 'senery', 'in', 'your', 'mind', 'so', 'well', 'I', 'would', 'recomend', 'it', 'even', 'to', 'people', 'who', 'hate', 'vid', '.', 'game', 'music', '!', 'I', 'have', 'played', 'the', 'game', 'Chrono', 'Cross', 'but', 'out', 'of', 'all', 'of', 'the', 'games', 'I', 'have', 'ever', 'played', 'it', 'has', 'the', 'best', 'music', '!', 'It', 'backs', 'away', 'from', 'crude', 'keyboarding', 'and', 'takes', 'a', 'fresher', 'step', 'with', 'grate', 'guitars', 'and', 'soulful', 'orchestras', '.', 'It', 'would', 'impress', 'anyone', 'who', 'cares', 'to', 'listen', '!', '^_^']

# %% [markdown]
# # Can you guess the language?
# Often in real applications not all documents carrying sentiment will be in English. We might want to detect what language is used or build specific features related to language

# %%
from langdetect import detect_langs

# %% [markdown]
# # Language of a string in Python
# 1. In Python there are a few libraries that can detect the language of a string. One of the library is <code>langdetect</code> because it is one of the better performing packages.
# 2. First import the detect_langs function from the langdetect package. Now imagine we have a string called foreign, which is a sentence in another language.
# 3. Our goal is to identify its language.
# 4. We apply the detect_langs function to our string. This function will return a list.
# 5. Each item of the list contains a pair of a language and a number saying how likely it is that the string is in this particular language.

# %%
foreign = 'Este libro ha sido uno de los mejores libros que he leido.'

# %%
detect_langs(foreign)
# Out:
# [es:0.9999967521936161]
